# %%
# 1) r = π · 8**4

import math as mt

x= mt.pi 

r= x*8**4

print(r)
# Out:
# 12867.963509103793

# %%
# 2) r = |1342 − 1677 · (9/7) − 6|

from fractions import Fraction

medio = Fraction(9, 7)

r= 1342-1677 * (medio) - 6

print(r)
# Out:
# -5741/7

# %%
# 3) r = 9!

r= 9*8*7*6*5*4*3*2*1

print(r)
# Out:
# 362880

# %%
# 4) r = log(7)

import math as mt

log = mt.log(7, 10)

r= log

print(r)
# Out:
# 0.8450980400142567

# %%
# 5) r = e0,555457

import math as mt

x= mt.e

r= x**0,555457

print(r)
# Out:
# (1.0, 555457)

# %%
# b) Calcule el valor de x 

import math as mt

from fractions import Fraction

z= 2 + mt.pi
y= 7 + 2 * 41**2

x= z/y


print(x)
# Out:
# 0.001526148012344848

# %%
import math as mt

import statistics as st

x = ["2", "-6", "27", "-8", "-9", "-21", "9", "5", "562", "mt.pi"]

y= [8, 9, -31, 18, 5, -18, 9, -22, 0, 9]


print (st.mean(y))
print (st.pvariance(y))
print (st.stdev(y))
# Out:
# -1.3
# 240.81
# 16.357465166298436

# %%
import pandas as pd

datos = {'sexo': ["h","m","h"],
         'peso': [60,90,80],
          'nivel educativo':["Lic","Bach","Phd"],
         'edad': [23,56,12]}

mi_df = pd.DataFrame(datos)
mi_df
# Out:
#   sexo  peso nivel educativo  edad
# 0    h    60             Lic    23
# 1    m    90            Bach    56
# 2    h    80             Phd    12
